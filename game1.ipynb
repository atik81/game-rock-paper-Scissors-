# %%
response = "yes"
while response == "yes":
 atik = input("atik: ")
 nadia = input("nadia: ")
 sadia = input("sadia: ")
 if atik == nadia ==sadia:
    print("it's a tie !!")
else:
    if atik == "rock" and nadia == "paper" and sadia == "scissor":
        print("atik is the winner !!")
    elif atik == "paper" and nadia == "rock" and sadia == "scissor":
        print("nadia is the winner !!")
    elif atik == "paper" and nadia == "scissor" and sadia == "rock":
        print("sadia is the winner!! ")

    elif atik == "scissor" and nadia == "paper" and sadia == "rock":
        print("atik is the winner !!")
    elif atik == "scissor" and nadia == "rock" and sadia == "paper":
        print("sadia is the winner !! ")
    elif atik == "rock" and nadia == "scissor" and sadia == "paper":
        print("nadia is the winner !! ")


    elif atik == "rock" and nadia == "rock" and sadia == "paper":
        print("sadia is the winner !! ")
    elif atik == "rock" and nadia == "rock" and sadia == "scissor":
        print("atik is the winner !! ")
    elif atik == "paper" and nadia == "paper" and sadia == "rock":
        print("nadia is the winner !! ")
    elif atik == "paper" and nadia == "paper" and sadia == "scissor":
        print("sadia is the winner !! ")
    elif atik == "scissor" and nadia == "scissor" and sadia == "rock":
        print("atik is the winner !! ")
    elif atik == "scissor" and nadia == "scissor" and sadia == "paper":
        print("nadia is the winner !! ")


    elif atik == "rock" and nadia == "paper" and sadia == "rock":
            print("sadia is the winner !! ")
    elif atik == "rock" and nadia == "scissor" and sadia == "rock":
        print("atik is the winner !! ")
    elif atik == "paper" and nadia == "rock" and sadia == "paper":
        print("nadia is the winner !! ")
    elif atik == "paper" and nadia == "scissor" and sadia == "paper":
        print("sadia is the winner !! ")
    elif atik == "scissor" and nadia == "rock" and sadia == "scissor":
        print("atik is the winner !! ")
    elif atik == "scissor" and nadia == "paper" and sadia == "scissor":
        print("nadia is the winner !! ")


    elif atik == "paper" and nadia == "rock" and sadia == "rock":
        print("sadia is the winner !! ")
    elif atik == "scissor" and nadia == "rock" and sadia == "rock":
        print("atik is the winner !! ")
    elif atik == "rock" and nadia == "paper" and sadia == "paper":
        print("nadia is the winner !! ")
    elif atik == "scissor" and nadia == "paper" and sadia == "paper":
        print("sadia is the winner !! ")
    elif atik == "rock" and nadia == "scissor" and sadia == "scissor":
        print("atik is the winner !! ")
    elif atik == "paper" and nadia == "scissor" and sadia == "scissor":
        print("nadia is the winner !! ")
response = str(input("DO YOU WANT TO PLAY ANOTHER GAME, YES OR NO\n"))

if response == "no":
    print ('game over. ')
